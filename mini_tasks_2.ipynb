# %%
#) topic: data visualization and pandas
#) highlights: 50 plus plots are tried

# %%
import pandas as pd

# %%
df_project = pd.DataFrame()
df_project['year'] = [
    2024,2023,2022,2021,2020,2019,
    2023,2024,2019,2020,2021,2022,
    2022,2023,2024,2021,2020,2019,
    2019,2023,2022,2021,2020,2019,
    2024,2020,2022,2021,2020,2019
    ]

df_project['field_expertise'] = [
    'ML Engineer','Data Scientist','Data Analyst', 'Data Engineer','AI Engineer','Big Data Engineer',
    'Data Engineer','AI Engineer','Data Engineer','Data Analyst','Data Scientist','Data Scientist',
    'ML Engineer','Data Scientist','Data Engineer', 'Data Engineer','AI Engineer','Big Data Engineer',
    'Big Data Engineer','AI Engineer','Data Engineer','Data Analyst','Data Scientist','Data Scientist',
    'ML Engineer','Data Scientist','Data Analyst', 'Data Engineer','AI Engineer','Big Data Engineer'
]

df_project['salary'] = [
    100,250,300,450,300,200,
    230,340,127,320,420,210,
    170,260,340,290,345,237,
    142,480,304,225,415,205,
    465,372,239,423,321,132
]

df_project['project_value'] = [
    1000.9,1220.5,1170.2,1300.5,1410.2,1360.3,
    1423.5,1134.7,1330.5,1247.8,1080.6,1034.9,
    1290.4,1430.5,1120.6,1042.3,1420.4,1089.6,
    1332.5,1442.6,1208.9,1240.5,1044.3,1182.7,
    1083.8,1123.5,1300.8,1240.7,1453.5,1480.8
    
]
df_project['location'] = [
    'India','US','UK','France','German','France',
    'Spain','German','Spain','UK','India','US',
    'India','France','UK','France','India','Spain',
    'Spain','India','France','UK','India','US',
    'India','US','UK','France','German','Spain',
]
df_project
# Out:
#     year    field_expertise  salary  project_value location
# 0   2024        ML Engineer     100         1000.9    India
# 1   2023     Data Scientist     250         1220.5       US
# 2   2022       Data Analyst     300         1170.2       UK
# 3   2021      Data Engineer     450         1300.5   France
# 4   2020        AI Engineer     300         1410.2   German
# 5   2019  Big Data Engineer     200         1360.3   France
# 6   2023      Data Engineer     230         1423.5    Spain
# 7   2024        AI Engineer     340         1134.7   German
# 8   2019      Data Engineer     127         1330.5    Spain
# 9   2020       Data Analyst     320         1247.8       UK
# 10  2021     Data Scientist     420         1080.6    India
# 11  2022     Data Scientist     210         1034.9       US
# 12  2022        ML Engineer     170         1290.4    India
# 13  2023     Data Scientist     260         1430.5   France
# 14  2024      Data Engineer     340         1120.6       UK
# ...

# %%
#) converting df to list
list_year= df_project['year'].tolist()
print(list_year)
# Out:
# [2024, 2023, 2022, 2021, 2020, 2019, 2023, 2024, 2019, 2020, 2021, 2022, 2022, 2023, 2024, 2021, 2020, 2019, 2019, 2023, 2022, 2021, 2020, 2019, 2024, 2020, 2022, 2021, 2020, 2019]

# %%
#) converting df to list
list_expertise= df_project['field_expertise'].tolist()
print(list_expertise)
# Out:
# ['ML Engineer', 'Data Scientist', 'Data Analyst', 'Data Engineer', 'AI Engineer', 'Big Data Engineer', 'Data Engineer', 'AI Engineer', 'Data Engineer', 'Data Analyst', 'Data Scientist', 'Data Scientist', 'ML Engineer', 'Data Scientist', 'Data Engineer', 'Data Engineer', 'AI Engineer', 'Big Data Engineer', 'Big Data Engineer', 'AI Engineer', 'Data Engineer', 'Data Analyst', 'Data Scientist', 'Data Scientist', 'ML Engineer', 'Data Scientist', 'Data Analyst', 'Data Engineer', 'AI Engineer', 'Big Data Engineer']

# %%
#) converting df to list
list_salary= df_project['salary'].tolist()
print(list_salary)
# Out:
# [100, 250, 300, 450, 300, 200, 230, 340, 127, 320, 420, 210, 170, 260, 340, 290, 345, 237, 142, 480, 304, 225, 415, 205, 465, 372, 239, 423, 321, 132]

# %%
#) converting df to list
list_project_value= df_project['project_value'].tolist()
print(list_project_value)
# Out:
# [1000.9, 1220.5, 1170.2, 1300.5, 1410.2, 1360.3, 1423.5, 1134.7, 1330.5, 1247.8, 1080.6, 1034.9, 1290.4, 1430.5, 1120.6, 1042.3, 1420.4, 1089.6, 1332.5, 1442.6, 1208.9, 1240.5, 1044.3, 1182.7, 1083.8, 1123.5, 1300.8, 1240.7, 1453.5, 1480.8]

# %%
#) converting df to list
list_location= df_project['location'].tolist()
print(list_location)
# Out:
# ['India', 'US', 'UK', 'France', 'German', 'France', 'Spain', 'German', 'Spain', 'UK', 'India', 'US', 'India', 'France', 'UK', 'France', 'India', 'Spain', 'Spain', 'India', 'France', 'UK', 'India', 'US', 'India', 'US', 'UK', 'France', 'German', 'Spain']

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#) converting list to arr
arr_year = np.array(list_year)
arr_year
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2023, 2024, 2019, 2020, 2021,
#        2022, 2022, 2023, 2024, 2021, 2020, 2019, 2019, 2023, 2022, 2021,
#        2020, 2019, 2024, 2020, 2022, 2021, 2020, 2019])

# %%
#) converting list to arr
arr_salary = np.array(list_salary)
arr_salary
# Out:
# array([100, 250, 300, 450, 300, 200, 230, 340, 127, 320, 420, 210, 170,
#        260, 340, 290, 345, 237, 142, 480, 304, 225, 415, 205, 465, 372,
#        239, 423, 321, 132])

# %%
#) converting list to arr
arr_project_value = np.array(list_project_value)
arr_project_value
# Out:
# array([1000.9, 1220.5, 1170.2, 1300.5, 1410.2, 1360.3, 1423.5, 1134.7,
#        1330.5, 1247.8, 1080.6, 1034.9, 1290.4, 1430.5, 1120.6, 1042.3,
#        1420.4, 1089.6, 1332.5, 1442.6, 1208.9, 1240.5, 1044.3, 1182.7,
#        1083.8, 1123.5, 1300.8, 1240.7, 1453.5, 1480.8])

# %%
#)plotting year vs salary
plt.figure(figsize=(4,4))
plt.bar(list_year,list_salary,color='#a83c32')

plt.xlabel("year")
plt.ylabel("salary")
plt.title("year vs salary")

plt.show()

# %%
#)plotting year vs project value
plt.figure(figsize=(4,4))
plt.bar(list_year,list_project_value,color='#a86532')

plt.xlabel("year")
plt.ylabel("project_value")

plt.title("year vs project_value")
plt.show()

# %%
#)plotting field expertise vs project value
plt.figure(figsize=(9,4))
plt.barh(list_expertise,list_project_value,color='#a88932')

plt.xlabel("project_value")
plt.ylabel("field_expertise")
plt.title("field_expertise vs project_value")

plt.show()

# %%
#)plotting field_expertise vs salary
plt.figure(figsize = (9,4))
plt.barh(list_expertise,list_salary,color='#9ca832')

plt.xlabel("salary")
plt.ylabel("field_expertise")
plt.title("field_expertise vs salary")

plt.show()

# %%
#) plotting year vs value
plt.figure(figsize = (5,4))
plt.bar(list_year,list_project_value,width=0.4)
plt.bar(list_year,list_project_value,bottom=list_salary,width=0.4)

plt.xlabel("year")
plt.ylabel("value")
plt.title("year vs value")
plt.legend(["salary", "project value"])

plt.show()

# %%
#) plotting location vs value
plt.figure(figsize = (5,4))
plt.bar(list_location,list_project_value,width=0.4)
plt.bar(list_location,list_project_value,bottom=list_salary,width=0.4)

plt.xlabel("location")
plt.ylabel("value")
plt.title("location vs value")
plt.legend(["salary", "project value"])

plt.show()

# %%
#) field_expertise vs value
plt.figure(figsize = (9,4))
plt.bar(list_expertise,list_project_value,width=0.4)
plt.bar(list_expertise,list_project_value,bottom=list_salary,width=0.4)

plt.xlabel("field_expertise")
plt.ylabel("value")
plt.title("field_expertise vs value")
plt.legend(["salary", "project value"])

plt.show()

# %%
#) plotting year vs value
sns.barplot(data=df_project,x ="year",y="project_value",hue="location")

plt.title("year vs value")
plt.show()

# %%
#) plotting year vs value
sns.barplot(data=df_project,x ="year",y="project_value",hue="field_expertise")

plt.title("year vs value")
plt.show()

# %%
#) plotting year vs value
sns.barplot(data=df_project,x ="location",y="project_value",hue="year")

plt.title("location vs value")
plt.show()

# %%
#) plotting location vs value
sns.barplot(data=df_project,x ="location",y="project_value",hue="field_expertise")

plt.title("location vs value")
plt.show()

# %%
#) plotting field_expertise vs value
fig,ax = plt.subplots(figsize=(9,4))
sns.barplot(data=df_project,x ="field_expertise",y="project_value",hue="location")

plt.title("field_expertise vs value")
plt.show()

# %%
df_project.info
# Out:
# <bound method DataFrame.info of     year    field_expertise  salary  project_value location
# 0   2024        ML Engineer     100         1000.9    India
# 1   2023     Data Scientist     250         1220.5       US
# 2   2022       Data Analyst     300         1170.2       UK
# 3   2021      Data Engineer     450         1300.5   France
# 4   2020        AI Engineer     300         1410.2   German
# 5   2019  Big Data Engineer     200         1360.3   France
# 6   2023      Data Engineer     230         1423.5    Spain
# 7   2024        AI Engineer     340         1134.7   German
# 8   2019      Data Engineer     127         1330.5    Spain
# 9   2020       Data Analyst     320         1247.8       UK
# 10  2021     Data Scientist     420         1080.6    India
# 11  2022     Data Scientist     210         1034.9       US
# 12  2022        ML Engineer     170         1290.4    India
# 13  2023     Data Scientist     260         1430.5   France
# ...

# %%
df_project.head()
# Out:
#    year field_expertise  salary  project_value location
# 0  2024     ML Engineer     100         1000.9    India
# 1  2023  Data Scientist     250         1220.5       US
# 2  2022    Data Analyst     300         1170.2       UK
# 3  2021   Data Engineer     450         1300.5   France
# 4  2020     AI Engineer     300         1410.2   German

# %%
#) 1.to know how many elements in df
df_project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             30 non-null     int64
#  1   field_expertise  30 non-null     object
#  2   salary           30 non-null     int64
#  3   project_value    30 non-null     float64
#  4   location         30 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
#) 2.to know how many elements in df
df_project.shape
# Out:
# (30, 5)

# %%
#) 3.to get the maximum value in df
df_project.max()
# Out:
# year                      2024
# field_expertise    ML Engineer
# salary                     480
# project_value           1480.8
# location                    US
# dtype: object

# %%
#) 4. to get summarization statistics of df
df_project.describe()
# Out:
#               year      salary  project_value
# count    30.000000   30.000000      30.000000
# mean   2021.233333  287.066667    1241.433333
# std       1.715715  105.157331     145.586683
# min    2019.000000  100.000000    1000.900000
# 25%    2020.000000  213.750000    1121.325000
# 50%    2021.000000  295.000000    1240.600000
# 75%    2022.750000  343.750000    1353.350000
# max    2024.000000  480.000000    1480.800000

# %%
#) 5. to count length of character in df

# %%
#) 6. to sort one column in df
df_project.sort_values(by=['project_value'])
# Out:
#     year    field_expertise  salary  project_value location
# 0   2024        ML Engineer     100         1000.9    India
# 11  2022     Data Scientist     210         1034.9       US
# 15  2021      Data Engineer     290         1042.3   France
# 22  2020     Data Scientist     415         1044.3    India
# 10  2021     Data Scientist     420         1080.6    India
# 24  2024        ML Engineer     465         1083.8    India
# 17  2019  Big Data Engineer     237         1089.6    Spain
# 14  2024      Data Engineer     340         1120.6       UK
# 25  2020     Data Scientist     372         1123.5       US
# 7   2024        AI Engineer     340         1134.7   German
# 2   2022       Data Analyst     300         1170.2       UK
# 23  2019     Data Scientist     205         1182.7       US
# 20  2022      Data Engineer     304         1208.9   France
# 1   2023     Data Scientist     250         1220.5       US
# 21  2021       Data Analyst     225         1240.5       UK
# ...

# %%
#) 7. to get the row data of a particular element
df_project.loc[df_project['salary'] == 132]
# Out:
#     year    field_expertise  salary  project_value location
# 29  2019  Big Data Engineer     132         1480.8    Spain

# %%
#) 8. to get the most common value in a coumn from df
df_project['field_expertise'].mode()
# Out:
# 0     Data Engineer
# 1    Data Scientist
# Name: field_expertise, dtype: object

# %%
#) 9. to count the repeated values in one column
df_project['year'].value_counts().head()
# Out:
# year
# 2020    6
# 2019    6
# 2022    5
# 2021    5
# 2024    4
# Name: count, dtype: int64

# %%
#) 10. to get a particular data in a column with ascending in another column
df_project[df_project['year'] ==2022].sort_values(by = 'salary')
# Out:
#     year field_expertise  salary  project_value location      Ratio
# 12  2022     ML Engineer     170         1290.4    India  11.894118
# 11  2022  Data Scientist     210         1034.9       US   9.628571
# 26  2022    Data Analyst     239         1300.8       UK   8.460251
# 2   2022    Data Analyst     300         1170.2       UK   6.740000
# 20  2022   Data Engineer     304         1208.9   France   6.651316

# %%
#) 11. to find out the ratio betweeen two column data
df_project['Ratio'] = df_project['year']/df_project['salary']
df_project['Ratio']
# Out:
# 0     20.240000
# 1      8.092000
# 2      6.740000
# 3      4.491111
# 4      6.733333
# 5     10.095000
# 6      8.795652
# 7      5.952941
# 8     15.897638
# 9      6.312500
# 10     4.811905
# 11     9.628571
# 12    11.894118
# 13     7.780769
# 14     5.952941
# 15     6.968966
# 16     5.855072
# 17     8.518987
# 18    14.218310
# 19     4.214583
# 20     6.651316
# 21     8.982222
# 22     4.867470
# 23     9.848780
# 24     4.352688
# 25     5.430108
# 26     8.460251
# 27     4.777778
# 28     6.292835
# 29    15.295455
# Name: Ratio, dtype: float64

# %%
#) 12. to get the count of ratio of two columns
df_project['Ratio'].value_counts()
# Out:
# Ratio
# 5.952941     2
# 20.240000    1
# 5.855072     1
# 6.292835     1
# 4.777778     1
# 8.460251     1
# 5.430108     1
# 4.352688     1
# 9.848780     1
# 4.867470     1
# 8.982222     1
# 6.651316     1
# 4.214583     1
# 14.218310    1
# 8.518987     1
# 6.968966     1
# 8.092000     1
# 7.780769     1
# 11.894118    1
# 9.628571     1
# 4.811905     1
# 6.312500     1
# 15.897638    1
# 8.795652     1
# 10.095000    1
# 6.733333     1
# 4.491111     1
# 6.740000     1
# 15.295455    1
# Name: count, dtype: int64

# %%
#)13. to get the maximum ratio
df_project['Ratio'].max()
# Out:
# 20.24

# %%
#)14. to get mean of one column data
df_project['project_value'].mean()
# Out:
# 1241.4333333333334

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#) 15. piechart location vs count 
df_project['location'].value_counts().plot(kind='pie',cmap='tab20c',figsize=(7,4))
plt.title("location vs count")

plt.show()

# %%
#) piechart year vs count
df_project['year'].value_counts().plot(kind='pie',cmap='tab20c',figsize=(7,4))
plt.title("year vs count")

plt.show()

# %%
#) piechart expertise vs count
df_project['field_expertise'].value_counts().plot(kind='pie',cmap='tab20c',figsize=(7,4))
plt.title("expertise vs count")

plt.show()

# %%
#)16.hist plot year vs frquency
df_project['year'].plot(kind='hist',figsize = (7,4),color='#71a832',width=0.4)
plt.title("year vs frequency")

plt.show()

# %%
#) plotting salary vs frequency
df_project['salary'].plot(kind='hist',figsize = (7,4),color='#32a873')
plt.title("salary vs frequency")

plt.show()

# %%
#) plotting project_value vs frequency
df_project['project_value'].plot(kind='hist',figsize = (7,4))
plt.title("project_value vs frequency")

plt.show()

# %%
#) plotting boxplot
df_project['year'].plot(kind='box',figsize = (7,4))
plt.title('boxplot with year')

plt.show()

# %%
#) plotting boxplot
df_project['salary'].plot(kind='box',figsize = (7,4))

plt.title('boxplot with salary')
plt.show()

# %%
#) plotting boxplot
df_project['project_value'].plot(kind='box', vert = False, figsize = (7,4))
plt.title('boxplot with project_value')

plt.show()

# %%
#) plotting boxplot
sns.boxplot(df_project,x='year',y='salary')
plt.title('year vs salary')

plt.show()

# %%
#) plotting boxplot
fig,ax = plt.subplots(figsize=(9,4))
sns.boxplot(df_project,x='field_expertise',y='salary',color = "brown")
plt.title('field_expertise vs salary')
plt.show()

# %%
#) plotting boxplot
fig,ax = plt.subplots(figsize=(9,4))
sns.boxplot(df_project,x='field_expertise',y='project_value')
plt.title('field_expertise vs salary')
plt.show()

# %%
#) plotting boxplot
sns.boxplot(df_project,x='location',y='salary',color='red')
plt.title('location vs salary')
plt.show()

# %%
#)17. to get the data of one column above certain value
df_project.loc[df_project['salary']>450]
# Out:
#     year field_expertise  salary  project_value location     Ratio
# 19  2023     AI Engineer     480         1442.6    India  4.214583
# 24  2024     ML Engineer     465         1083.8    India  4.352688

# %%
#)18. to get the data of one column below certain value
df_project.loc[df_project['project_value']<1100]
# Out:
#     year    field_expertise  salary  project_value location      Ratio
# 0   2024        ML Engineer     100         1000.9    India  20.240000
# 10  2021     Data Scientist     420         1080.6    India   4.811905
# 11  2022     Data Scientist     210         1034.9       US   9.628571
# 15  2021      Data Engineer     290         1042.3   France   6.968966
# 17  2019  Big Data Engineer     237         1089.6    Spain   8.518987
# 22  2020     Data Scientist     415         1044.3    India   4.867470
# 24  2024        ML Engineer     465         1083.8    India   4.352688

# %%
#)19. to count the data of one column below certain value
df_project.loc[df_project['project_value']<1300].shape
# Out:
# (18, 6)

# %%
#) 20. to get the data of one column with particular values
df_project.query('year==2022')
# Out:
#     year field_expertise  salary  project_value location      Ratio
# 2   2022    Data Analyst     300         1170.2       UK   6.740000
# 11  2022  Data Scientist     210         1034.9       US   9.628571
# 12  2022     ML Engineer     170         1290.4    India  11.894118
# 20  2022   Data Engineer     304         1208.9   France   6.651316
# 26  2022    Data Analyst     239         1300.8       UK   8.460251

# %%
#) 21. to get scatterplot
ax=sns.scatterplot(data=df_project,x='salary',y='project_value')
plt.title("salary vs project_value")

plt.show()

# %%
#)22. to count particular data in two column from df
(
    (df_project['field_expertise'] == 'Data Scientist') &
    (df_project['location'] == 'US')
).sum()
# Out:
# 4

# %%
#)23. to get particular data in two column from df
df_project.loc[(
    (df_project['field_expertise'] == 'Data Scientist') &
    (df_project['location'] == 'US')
)]
# Out:
#     year field_expertise  salary  project_value location     Ratio
# 1   2023  Data Scientist     250         1220.5       US  8.092000
# 11  2022  Data Scientist     210         1034.9       US  9.628571
# 23  2019  Data Scientist     205         1182.7       US  9.848780
# 25  2020  Data Scientist     372         1123.5       US  5.430108

# %%
#)to get particular data in two column from df
df_project.loc[(
    (df_project['year'] == 2022) &
    (df_project['location'] == 'US')
)]
# Out:
#     year field_expertise  salary  project_value location     Ratio
# 11  2022  Data Scientist     210         1034.9       US  9.628571

# %%
#)to get particular data in two column from df
df_project.loc[(
    (df_project['field_expertise'] == 'Data Scientist') &
    (df_project['location'] == 'India')
)]
# Out:
#     year field_expertise  salary  project_value location     Ratio
# 10  2021  Data Scientist     420         1080.6    India  4.811905
# 22  2020  Data Scientist     415         1044.3    India  4.867470

# %%
#) 24. to get particular data from different data in two columns
df_project[(df_project['year'] == 2022) | (df_project['location'] == 'India')]
# Out:
#     year field_expertise  salary  project_value location      Ratio
# 0   2024     ML Engineer     100         1000.9    India  20.240000
# 2   2022    Data Analyst     300         1170.2       UK   6.740000
# 10  2021  Data Scientist     420         1080.6    India   4.811905
# 11  2022  Data Scientist     210         1034.9       US   9.628571
# 12  2022     ML Engineer     170         1290.4    India  11.894118
# 16  2020     AI Engineer     345         1420.4    India   5.855072
# 19  2023     AI Engineer     480         1442.6    India   4.214583
# 20  2022   Data Engineer     304         1208.9   France   6.651316
# 22  2020  Data Scientist     415         1044.3    India   4.867470
# 24  2024     ML Engineer     465         1083.8    India   4.352688
# 26  2022    Data Analyst     239         1300.8       UK   8.460251

# %%
#)to get particular data in two column from df
df_project[(df_project['field_expertise'] == 'ML Engineer') | (df_project['location'] == 'UK')]
# Out:
#     year field_expertise  salary  project_value location      Ratio
# 0   2024     ML Engineer     100         1000.9    India  20.240000
# 2   2022    Data Analyst     300         1170.2       UK   6.740000
# 9   2020    Data Analyst     320         1247.8       UK   6.312500
# 12  2022     ML Engineer     170         1290.4    India  11.894118
# 14  2024   Data Engineer     340         1120.6       UK   5.952941
# 21  2021    Data Analyst     225         1240.5       UK   8.982222
# 24  2024     ML Engineer     465         1083.8    India   4.352688
# 26  2022    Data Analyst     239         1300.8       UK   8.460251

# %%
#) 21. to get scatterplot
fig,ax = plt.subplots(figsize=(7,4))
ax=sns.scatterplot(data=df_project,x='salary',y='project_value',hue='year',ax=ax)
plt.title("salary vs project_value")

plt.show()

# %%
#) to get scatterplot
fig,ax = plt.subplots(figsize=(7,4))
ax=sns.scatterplot(data=df_project,x='salary',y='project_value',hue='field_expertise',ax=ax)

plt.title("salary vs project_value")
plt.show()

# %%
#)to get scatterplot
fig,ax = plt.subplots(figsize=(7,4))
ax=sns.scatterplot(data=df_project,x='salary',y='project_value',hue='location',ax=ax)
plt.title("salary vs project_value")

plt.show()

# %%
#) to get histplot
sns.barplot(df_project,x='year',y='salary',color='purple',width=0.5)
plt.title("year vs salary")

plt.show()

# %%
#) to get histplot
sns.barplot(df_project,x='location',y='salary',color='red',width=0.5)
plt.title("location vs salary")

plt.show()

# %%
#) to get histplot
fig,ax = plt.subplots(figsize=(9,4))
sns.barplot(df_project,x='field_expertise',y='salary',color='yellow',width=0.5)
plt.title("field_expertise vs salary")

plt.show()

# %%
#)hist plot
df_project.loc[df_project['salary']>400,'salary'].plot(kind='hist')
plt.title("salary with frequency above 400")

plt.show()

# %%
#)histplot
df_project.loc[df_project['project_value']>1300,'project_value'].plot(kind='hist')
plt.title("project value with frequenct above 1300")
plt.show()

# %%
#) to get 2022 row data
df_2022 = df_project.query('year==2022')
df_2022
# Out:
#     year field_expertise  salary  project_value location
# 2   2022    Data Analyst     300         1170.2       UK
# 11  2022  Data Scientist     210         1034.9       US
# 12  2022     ML Engineer     170         1290.4    India
# 20  2022   Data Engineer     304         1208.9   France
# 26  2022    Data Analyst     239         1300.8       UK

# %%
#)hist plot
fig,ax = plt.subplots(figsize=(7,4))
sns.barplot(df_2022,x='field_expertise',y='salary',color='green',width=0.4)
plt.title("field_expertise vs salary in 2022")
plt.show()

# %%
#)hist plot
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(df_2022,x='location',y='salary',color='orange',width=0.5)
plt.title("location vs salary in 2022")

plt.show()

# %%
#)hist plot
fig,ax = plt.subplots(figsize=(7,4))
sns.barplot(df_2022,x='field_expertise',y='project_value',color='purple',width=0.4)
plt.title("field_expertise vs project value in 2022")

plt.show()

# %%
#)histplot
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(df_2022,x='location',y='project_value',width=0.4)
plt.title("location vs project_value in 2022")

plt.show()

# %%
#) to get the row data of 2023 in df
df_2023 = df_project.query('year==2023')
df_2023
# Out:
#     year field_expertise  salary  project_value location
# 1   2023  Data Scientist     250         1220.5       US
# 6   2023   Data Engineer     230         1423.5    Spain
# 13  2023  Data Scientist     260         1430.5   France
# 19  2023     AI Engineer     480         1442.6    India

# %%
#) histplot
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(df_2023,x='field_expertise',y='salary',width=0.4,color='green')
plt.title("field_expertise vs salary in 2023")
plt.show()

# %%
#) histplot
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(df_2023,x='location',y='salary',color='green',width=0.4)
plt.title("location vs salary in 2023")

plt.show()

# %%
#)histplot
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(df_2023,x='field_expertise',y='project_value',color = "orange",width=0.4)
plt.title("field_expertise vs project_value in 2023")

plt.show()

# %%
#)histplot
fig,ax = plt.subplots(figsize=(4,4))
sns.barplot(df_2023,x='location',y='project_value',color='brown',width=0.4)
plt.title('location vs project value in 2023')
plt.show()

# %%
#) to get the row data of 'data scientist'
df_ds = df_project[df_project['field_expertise'] == 'Data Scientist']
df_ds
# Out:
#     year field_expertise  salary  project_value location
# 1   2023  Data Scientist     250         1220.5       US
# 10  2021  Data Scientist     420         1080.6    India
# 11  2022  Data Scientist     210         1034.9       US
# 13  2023  Data Scientist     260         1430.5   France
# 22  2020  Data Scientist     415         1044.3    India
# 23  2019  Data Scientist     205         1182.7       US
# 25  2020  Data Scientist     372         1123.5       US

# %%
#)histplot
plt.figure(figsize=(6,4))
sns.lineplot(data=df_ds,x ="salary",y= "project_value",color='#a8327d')
plt.title('salary vs project value for data scientist')

plt.show()

# %%
#)histplot
plt.figure(figsize=(6,4))
sns.lineplot(data=df_ds,x ="year",y= "salary",color='#a83240')
plt.title('year vs salary for data scientist')

plt.show()

# %%
#)histplot
plt.figure(figsize=(6,4))
sns.lineplot(data=df_ds,x ="year",y= "project_value")
plt.title('year vs project value for data scientist')

plt.show()

# %%
#)violin plot
sns.violinplot(df_project,x='year',y='project_value', color = "green")
plt.title('year vs project value')

plt.show()

# %%
#) violin plot
sns.violinplot(df_project,x='year',y='salary')
plt.title('year vs salary')

plt.show()

# %%
#) violin plot
sns.violinplot(df_project,x='location',y='salary',color = "orange")
plt.title('location vs salary')

plt.show()

# %%
#)violin plot
sns.violinplot(df_project,x='location',y='project_value',color = "violet")
plt.title('location vs project value')

plt.show()

# %%
#)violin plot
fig,ax = plt.subplots(figsize=(9,4))
sns.violinplot(df_project,x='field_expertise',y='salary',color ='yellow')
plt.title('field_expertise vs salary')

plt.show()

# %%
#)pairplots
sns.pairplot(data=df_project,hue="field_expertise")
plt.show()
